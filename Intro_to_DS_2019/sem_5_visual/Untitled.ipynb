# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(1,10, 100)
y = np.sin(x)

plt.plot(x, y, color='red', label='няшня линия')

plt.plot(x + 1, y, color='green', marker='+',
                 linestyle='dashed',
                linewidth=0.2, markersize=8,
                label ='чистая линия')

plt.title('Графический график', fontsize=16)
plt.xlabel('ось иксов')
plt.xticks([x for x in range(0,12,2)])

plt.fill_between(x, np.sin(x-1), np.sin(x), alpha=0.1)

plt.legend()

plt.show()

# %%
[x for x in range(0,12,2)]
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
plt.fill_between(x, x-1, x+1, color = [(.9,.3,.1)], alpha = 1)
plt.xlim((0,10))
# Out:
# (0, 10)
