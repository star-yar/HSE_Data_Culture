# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,200)
y = np.sin(x)
z = np.sin(x + 1)

plt.figure(figsize=(10,2)) # размер картинка

plt.plot(x, y, color='red', alpha=0.2, label='грфик')
plt.plot(x, z, linestyle='dashed', label='не график')

plt.fill_between(x, y, z, alpha=0.2,color=(0.5,0.1,0.9))
plt.title('ГРАФИЧЕСКИЙ ГРАФ', fontsize=18)
plt.xlabel('ось х')
plt.ylabel('ось y')

plt.legend()
