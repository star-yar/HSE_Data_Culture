# %% [markdown]
# В названии файла укажите номер группы и вашу фамилию.
#
# # Задание 1. Визуализация.
#
# Перед вам данные о жилье в округе Кинг, штат Вашингтон. <br>
# В первом задании вам необходимо воспроизвести два графика.
# Вариант 1: делает все для данных с bedrooms до 6 <br>
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-09-27%20%D0%B2%2022.10.58.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-09-27%20%D0%B2%2022.10.58.png)
# Вариант 2: делает все для данных с bedrooms от 6 до 11 <br>
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-09-27%20%D0%B2%2022.12.02.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-09-27%20%D0%B2%2022.12.02.png)

# %% [markdown]
# ## Слот для загрузки библиотек

# %% [markdown]
# ## Слот для загрузки данных

# %% [markdown]
# ## Слот для выполнения задания

# %% [markdown]
# # Задник 2. Выбор данных из датафрейма
#
# Заново загрузите данные (!).
# Строго запрещается осуществлять отбор данных по индексам, нужно сделать срез данных по столбцам.
#
# Вариант 1 должен выбрать данные так, чтобы получить следующую таблицу:
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-09-27%20%D0%B2%2022.34.41.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-09-27%20%D0%B2%2022.34.41.png)
#
# Вариант 2 должен выбрать данные так, чтобы получить следующую таблицу:
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-09-27%20%D0%B2%2022.35.51.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202018-09-27%20%D0%B2%2022.35.51.png)

# %% [markdown]
# ## Слот для загрузки библиотек

# %% [markdown]
# ## Слот для загрузки данных

# %% [markdown]
# ## Слот для выполнения задания
