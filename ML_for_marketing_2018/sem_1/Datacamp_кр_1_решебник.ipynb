# %% [markdown]
# # Задание 1. Визуализация.
# Перед вами данные по экспорту кофе с 1999 года по 2014.
#
# Ваша задача нарисовать два графика на одном поле. На первом графике отобразите данные по экспорту из всех стран для :
# - вариант 1: 2000 года
# - вариант 2: 2002 года
# - вариант 3: 2004 года
# - вариант 4: 2007 года
#
# в виде точечной диаграммы.
# Не забудьте оформить график! <br>
#
# 1) Переверните надписи по оси X на 45 градусов; <br>
# 2) Добавьте подпись осей: ось X называется "Country", ось Y называется  "Tons per year" <br>
# 3) Добавьте название графика "Coffee Export in ___ " и укажите, в каком конкретно году
#
#
# На втором графике отобразите информацию по стране за все года наблюдения:
# - вариант 1: Бразилия
# - вариант 2: Мексика
# - вариант 3: Канада
# - вариант 4: Гватемала
#
#
# Не забудьте оформить график! <br>
#
# 0) Поменяйте цвет графика на любой вам симпатичный;  <br>
# 1) Добавьте подпись осей: ось X называется "Year", ось Y называется  "Tons per year" <br>
# 2) Добавьте название графика Coffee Export in COUNTRY и укажите, в какой конкретно стране. <br>
# 3) Отметьте на графике стрелкой год, в котором экспорт был максимальный, и подпишите на графике, какой это был год текстом Maximum  in YEAR (возможно, немножко придется поугадать, где ставить надпись)  <br>
# 4) Уберите подписи по оси X; <br>

# %% [markdown]
# ## Слот для загрузки библиотек

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Слот для загрузки данных

# %%
data = pd.read_excel('/Users/ElenTevanyan/Downloads/Data_for_exercise_1.xlsx')

# %% [markdown]
# ## Слот для выполнения задания 1.

# %%
plt.subplot(2,1,1)
plt.scatter(x =data[data.Year == 1999].Country, y = data[data.Year == 1999].All)
plt.tight_layout()
plt.xticks(rotation = 45)
plt.xlabel('Country')
plt.ylabel('Tons per year')
plt.title('Coffee Export in 1999')
plt.show()

plt.subplot(2,1,1)
plt.plot(data[data.Country == 'MEXICO'].All)
plt.annotate('Maximum', xy = (yr_max, cs_max), xytext = (yr_max + 5, cs_max + 5), arrowprops=dict(facecolor='black'))
plt.tight_layout()
plt.show()

# %%
data[data.Country == 'MEXICO']
# Out:
#     Country      All  Year
# 3    MEXICO  445.546  1999
# 10   MEXICO  463.641  2000
# 17   MEXICO  185.854  2001
# 24   MEXICO  182.505  2002
# 31   MEXICO  151.536  2003
# 38   MEXICO  169.185  2004
# 45   MEXICO  203.226  2005
# 52   MEXICO  249.170  2006
# 59   MEXICO  282.117  2007
# 66   MEXICO  318.491  2008
# 73   MEXICO  330.027  2009
# 80   MEXICO  342.160  2010
# 87   MEXICO  600.899  2011
# 94   MEXICO  588.353  2012
# 101  MEXICO  473.574  2013
# 108  MEXICO  397.908  2014

# %% [markdown]
# # Задание 2. Программирование и Pandas.
#
# В этом задании вы будете работать с данными о пассажирах Титаника.
# Напомним, что колонки в датасете обозначают:
# - PassengerId: Номер пассажира
# - Survived: Статус выживаемости
# - Pclass: Класс обслуживания
# - Name: имя
# - Sex: Пол
# - Age: Возраст
# - SibSp: Количество братьев или сестер на борту
# - Parch: Количество родителей или других родственников на борту
# - Ticket: Номер билета
# - Fare: Стоимость билета
# - Cabin: Номер каюты
# - Embarked: Пристань посадки
#
#
# - Вариант 1: Выберите всех мужчин в таблице, чей возраст был в интервале от 22 до 40 лет. Сохраните в отдельную таблицу. В цикле посчитайте, сколько в сумме заплатили мужчины за пребывание на корабле.
# - Вариант 2: Выберите всех женщин в таблице, чей возраст был в интервале от 16 до 35 лет. Сохраните в отдельную таблицу. В цикле посчитайте, сколько в сумме заплатили женщины за пребывание на корабле.
# - Вариант 3: Выберите всех пассажиров первого класса в таблице, у которых были братья или сестры на корабле. Сохраните в отдельную таблицу. В цикле посчитайте, сколько в сумме заплатили эти пассажиры за пребывание на корабле.
# - Вариант 3: Выберите всех пассажиров третьего класса в таблице, у которых были родители или другие родственники на корабле. Сохраните в отдельную таблицу. В цикле посчитайте, сколько в сумме заплатили эти пассажиры за пребывание на корабле.

# %% [markdown]
# ## Слот для загрузки библиотек

# %%
import pandas as pd

# %% [markdown]
# ## Слот для загрузки данных

# %%
data = pd.read_csv('/Users/ElenTevanyan/Documents/Преподавание/Датасеты/titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
